# %% [markdown]
# -----
# #### 데이터 불러오기

# %%
import pandas as pd

# %%
station = pd.read_csv("../../Data/은평구_스테이션_군집화_1차.csv")

# %%
cluster5 = station[station.cluster_12_custom == 5]
st3 = cluster5[cluster5.대여소_ID.isin(['ST-2247','ST-2252','ST-2425'])]

# %%
st3
# Out:
#     Unnamed: 0   대여소_ID                     주소1  주소2         위도          경도  \
# 38          38  ST-2425     서울특별시 은평구 신사동 371-1  NaN  37.599316  126.907593
# 39          39  ST-2252  서울특별시 은평구 가좌로 316 상신교회  NaN  37.595810  126.910263
# 40          40  ST-2247     서울특별시 은평구 신사동 178-9  NaN  37.591862  126.906082
#
#     1분기_전체건수  2분기_전체건수  3분기_전체건수  4분기_전체건수  연간_전체건수  cluster_12_custom
# 38      4284      9014      7642      6550    27490                  5
# 39      3634      8630      7076      5898    25238                  5
# 40      2192      5282      4232      4170    15876                  5
