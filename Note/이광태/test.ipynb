# %% [markdown]
# ---
# ### 이광태 테스트 노트

# %%
import pandas as pd

# %%
df = pd.read_csv('../../Data/은평구_스테이션_군집화_1차.csv')

# %%
# 3구역 군집화 시각화
import folium

# %%
seoul_map = folium.Map(
  location=[37.55,126.98],
  zoom_start=11
)

for 대여소_ID,위도,경도,연간_전체건수 in zip(data_result.대여소_ID, data_result.위도,data_result.경도,data_result.연간_전체건수):
  popup = folium.Popup(대여소_ID, max_width=200)
  folium.Marker(
    [위도, 경도],
    popup=popup
  ).add_to(seoul_map)

  
  folium.CircleMarker(
    [위도, 경도],
    radius=연간_전체건수/total*100*2.5,
    color = 'skyblue',
    fill=True,
    fill_color='skyblue',
    fill_opacity=0.4,
    tooltip=f"전체건수{연간_전체건수}",
  ).add_to(seoul_map)

# %% [markdown]
# # 3구역 station가져오기

# %%
# Out:
#       기준_날짜 집계_기준 시작_대여소_ID    시작_대여소명 종료_대여소_ID    종료_대여소명  전체_건수  전체_이용_분  \
# 0  20240101  출발시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    1.0      4.0
# 1  20240101  도착시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    1.0      4.0
# 2  20240101  도착시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    2.0      7.0
# 3  20240101  출발시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    2.0      7.0
# 4  20240101  도착시간   ST-2263  진관동_108_6    ST-481  구산동_062_1    1.0     12.0
#
#    전체_이용_거리   기준_시간
# 0     612.0  1645.0
# 1     612.0  1650.0
# 2    1248.0  1635.0
# 3    1248.0  1630.0
# 4    2992.0  1400.0

# %%
data_result = pd.read_csv('../../Data/gtlee_data/gt_3구역_1027_2263_3126.csv')

# %%
print('ST-1027',data_result[(data_result.시작_대여소_ID == 'ST-1027')].shape)
print('ST-2263',data_result[(data_result.시작_대여소_ID == 'ST-2263')].shape)
print('ST-3126',data_result[(data_result.시작_대여소_ID == 'ST-3126')].shape)
# Out:
# ST-1027 (11564, 10)
# ST-2263 (10410, 10)
# ST-3126 (10556, 10)

# %%
data_result.head()
# Out:
#       기준_날짜 집계_기준 시작_대여소_ID    시작_대여소명 종료_대여소_ID    종료_대여소명  전체_건수  전체_이용_분  \
# 0  20240101  출발시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    1.0      4.0
# 1  20240101  도착시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    1.0      4.0
# 2  20240101  도착시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    2.0      7.0
# 3  20240101  출발시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    2.0      7.0
# 4  20240101  도착시간   ST-2263  진관동_108_6    ST-481  구산동_062_1    1.0     12.0
#
#    전체_이용_거리   기준_시간
# 0     612.0  1645.0
# 1     612.0  1650.0
# 2    1248.0  1635.0
# 3    1248.0  1630.0
# 4    2992.0  1400.0

# %%
data_result.loc[:,'기준_시간_int'] = data_result.loc[:,'기준_시간'].astype(int)

# for i in data_result.index:
#   data_result.loc[i,'기준_날짜_str'] = data_result.loc[i,'기준_날짜'].astype(str)

# %%
data_result.loc[:,'기준_시간_str'] = data_result.loc[:,'기준_시간_int'].astype(str)

# %%
data_result.tail()
# Out:
#           기준_날짜 집계_기준 시작_대여소_ID    시작_대여소명 종료_대여소_ID     종료_대여소명  전체_건수  \
# 32525  20241231  출발시간   ST-3126  진관동_076_1   ST-1483   진관동_108_1    1.0
# 32526  20241231  출발시간   ST-3126  진관동_076_1    ST-453   진관동_011_3    1.0
# 32527  20241231  출발시간   ST-2263  진관동_004_2    ST-453   진관동_011_3    1.0
# 32528  20241231  도착시간   ST-3126  진관동_076_1    ST-453   진관동_011_3    1.0
# 32529  20241231  도착시간   ST-3126  진관동_076_1   ST-3028  불광2동_008_1    1.0
#
#        전체_이용_분  전체_이용_거리   기준_시간  기준_시간_int 기준_시간_str
# 32525     43.0    1560.0  1900.0       1900      1900
# 32526      3.0     639.0   735.0        735      0735
# 32527      6.0     916.0  1955.0       1955      1955
# 32528      2.0     495.0   950.0        950      0950
# 32529      5.0     975.0   800.0        800      0800

# %%
for index in data_result.index:
  if len(data_result.loc[index,'기준_시간_str']) == 3:
    data_result.loc[index,'기준_시간_str'] = '0'+data_result.loc[index,'기준_시간_str']

# %%
# data_result['기준_날짜_str'] = pd.to_datetime(data_result['기준_날짜'].astype(str))

# %%
data_result.head()
# Out:
#       기준_날짜 집계_기준 시작_대여소_ID    시작_대여소명 종료_대여소_ID    종료_대여소명  전체_건수  전체_이용_분  \
# 0  20240101  출발시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    1.0      4.0
# 1  20240101  도착시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    1.0      4.0
# 2  20240101  도착시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    2.0      7.0
# 3  20240101  출발시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    2.0      7.0
# 4  20240101  도착시간   ST-2263  진관동_108_6    ST-481  구산동_062_1    1.0     12.0
#
#    전체_이용_거리   기준_시간  기준_날짜_str 기준_시간_str 기준_시간_str_d 기준_시간_str_dd
# 0     612.0  1645.0 2024-01-01    1645.0     1645:00     16:45:00
# 1     612.0  1650.0 2024-01-01    1650.0     1650:00     16:50:00
# 2    1248.0  1635.0 2024-01-01    1635.0     1635:00     16:35:00
# 3    1248.0  1630.0 2024-01-01    1630.0     1630:00     16:30:00
# 4    2992.0  1400.0 2024-01-01    1400.0     1400:00     14:00:00

# %%
#data_result.loc[:,'기준_시간_str_d'] = data_result.loc[:,'기준_시간_str'].str.replace('.0',':00')

# %%
#data_result['기준_시간_str_dd'] = data_result['기준_시간_str_d'][:2] +':'+ data_result['기준_시간_str_d'][2:]

# %%
data_result.tail()
# Out:
#           기준_날짜 집계_기준 시작_대여소_ID    시작_대여소명 종료_대여소_ID     종료_대여소명  전체_건수  \
# 32525  20241231  출발시간   ST-3126  진관동_076_1   ST-1483   진관동_108_1    1.0
# 32526  20241231  출발시간   ST-3126  진관동_076_1    ST-453   진관동_011_3    1.0
# 32527  20241231  출발시간   ST-2263  진관동_004_2    ST-453   진관동_011_3    1.0
# 32528  20241231  도착시간   ST-3126  진관동_076_1    ST-453   진관동_011_3    1.0
# 32529  20241231  도착시간   ST-3126  진관동_076_1   ST-3028  불광2동_008_1    1.0
#
#        전체_이용_분  전체_이용_거리   기준_시간 기준_날짜_str 기준_시간_str 기준_시간_str_d 기준_시간_str_dd
# 32525     43.0    1560.0  1900.0       NaN    1900.0     1900:00     19:00:00
# 32526      3.0     639.0   735.0       NaN     735.0      735:00      73:5:00
# 32527      6.0     916.0  1955.0       NaN    1955.0     1955:00     19:55:00
# 32528      2.0     495.0   950.0       NaN     950.0      950:00      95:0:00
# 32529      5.0     975.0   800.0       NaN     800.0      800:00      80:0:00

# %%
#data_result.loc[:,'기준_시간_str_d'][0][:2] + ":" + data_result.loc[:,'기준_시간_str_d'][0][2:]

for index in data_result.index:
  data_result.loc[index,'기준_시간_str_d'] = data_result.loc[index,'기준_시간_str'][:2] +':'+ data_result.loc[index,'기준_시간_str'][2:] + ':00'
  print(data_result.loc[index,'기준_시간_str_d'])
# Out:
# 16:45:00
# 16:50:00
# 16:35:00
# 16:30:00
# 14:00:00
# 13:15:00
# 13:50:00
# 18:05:00
# 18:15:00
# 04:00:00
# 22:40:00
# 22:35:00
# 23:45:00
# 23:55:00
# 01:00:00
# 22:00:00
# 22:10:00
# 5::00
# 04:25:00
# 12:00:00
# 11:25:00
# 11:25:00
# 11:25:00
# 11:05:00
# 11:40:00
# 11:40:00
# 11:40:00
# 11:35:00
# 12:50:00
# 13:10:00
# 12:30:00
# 12:45:00
# 10:55:00
# 09:55:00
# 09:50:00
# 10:15:00
# 20:25:00
# 21:00:00
# 23:30:00
# 23:25:00
# 21:35:00
# 22:00:00
# 22:05:00
# 21:50:00
# 20:15:00
# 12:40:00
# 12:40:00
# 11:45:00
# 12:05:00
# 12:05:00
# 12:00:00
# 12:00:00
# 13:35:00
# 13:20:00
# 13:15:00
# 13:15:00
# 09:20:00
# 09:10:00
# 11:25:00
# 11:20:00
# 10:40:00
# 10:30:00
# 17:00:00
# 16:30:00
# 16:35:00
# 17:10:00
# 14:35:00
# 14:35:00
# 15:45:00
# 15:45:00
# 15:55:00
# 15:35:00
# 18:30:00
# 18:40:00
# 18:20:00
# 18:15:00
# 18:15:00
# 18:05:00
# 18:10:00
# 19:45:00
# 19:50:00
# 19:55:00
# 20:10:00
# 20:00:00
# 20:00:00
# 20:00:00
# 19:30:00
# 19:20:00
# 08:10:00
# 08:10:00
# 08:05:00
# ...

# %%
arr_index = []
for index in data_result.index:
  if len(data_result.loc[index,'기준_시간_str_d']) != 8:
    arr_index.append(index)


arr_index
# Out:
# [17,
#  113,
#  114,
#  868,
#  902,
#  1222,
#  1584,
#  1585,
#  1661,
#  1999,
#  2000,
#  2058,
#  2059,
#  2344,
#  2345,
#  2355,
#  2357,
#  2457,
#  2544,
#  2545,
#  2775,
#  4238,
#  4348,
#  4349,
#  4350,
#  4351,
#  4412,
#  4522,
#  4523,
#  4524,
#  4525,
#  4526,
#  4527,
#  4551,
#  4552,
#  4825,
#  4826,
#  4972,
#  4974,
#  4975,
#  4976,
#  4977,
#  5093,
#  5380,
#  5381,
#  5383,
#  5384,
#  5385,
#  5595,
#  5656,
#  5657,
#  5658,
#  5659,
#  5892,
#  5893,
#  6305,
#  6306,
#  6307,
#  6308,
#  6445,
#  6515,
#  6516,
#  7004,
#  7005,
#  7105,
#  7106,
#  7447,
#  7448,
#  7512,
#  7513,
#  7514,
#  7598,
#  7599,
#  7601,
#  7783,
#  7784,
#  8231,
#  8290,
#  8291,
#  8711,
#  8712,
#  8713,
#  9191,
#  9193,
#  9545,
#  9546,
#  9547,
#  9549,
#  9550,
#  9551,
#  9552,
#  9553,
#  10520,
#  10521,
#  10832,
#  10833,
#  11559,
#  11560,
#  11561,
#  11562,
#  11851,
#  11852,
#  11853,
#  11854,
#  11893,
#  11894,
#  12240,
#  12241,
#  12242,
# ...

# %%
data_result.loc[arr_index,'기준_시간_d'] = data_result.loc[arr_index,'기준_시간_d'].str.replace('.0','')

# %%
arr_index = []
for index in data_result.index:
  if len(data_result.loc[index,'날짜']) != 17:
    arr_index.append(index)


arr_index
# Out:
# [17,
#  4525,
#  4526,
#  10521,
#  10832,
#  14420,
#  14447,
#  15059,
#  15516,
#  15517,
#  15954,
#  15955,
#  15960,
#  16227,
#  17311,
#  17710,
#  17712,
#  17713,
#  17977,
#  18219,
#  18878,
#  18936,
#  19155,
#  19178,
#  19181,
#  20257,
#  21030,
#  21317,
#  21525,
#  22430,
#  22633,
#  22634,
#  23866,
#  23867,
#  23868,
#  24614,
#  24641,
#  24695,
#  24696,
#  25499,
#  25539,
#  25867,
#  25967,
#  26605,
#  26675,
#  27069,
#  27268,
#  28344,
#  28794,
#  29026,
#  30887,
#  31075,
#  31314]

# %%
data_result['datetime'] = pd.to_datetime(data_result['날짜'])

# %%
data_result.drop(
  ['기준_시간_str',	'기준_시간_str_d', '기준_날짜_str', '날짜','기준_시간_d'],
  axis='columns',
  inplace=True
)

# %%
for index in data_result.index:
  data_result.loc[index,'hour'] = data_result.loc[index,'datetime'].hour

# %%
data_result.sort_values(
  by=['시작_대여소_ID','기준_날짜','hour']
).to_csv('../../Data/gtlee_data/sorted_data.csv',index=None)

# %%
for index in data_result.index:
  data_result.loc[index,'요일'] = data_result.loc[index,'datetime'].day_name()

# %%
data_result['hour'] = data_result['datetime']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8548\2295224899.py in ?()
# ----> 1 data_result['hour'] = pd.to_datetime(data_result['datetime']).hour
#
# c:\Users\tj\anaconda3\envs\py312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'hour'

# %%
data_result.drop(
  '기준_시간_int',
  axis='columns',
  inplace=True
)

# %%
data_result.drop(
  data_result[(data_result.전체_이용_분 == 0) & (data_result.전체_이용_거리 == 0)].index,
  axis='rows',
  inplace=True
)

# %%
data_result[(data_result.전체_이용_분 == 0) & (data_result.전체_이용_거리 == 0)].index
# Out:
# Index([], dtype='int64')

# %%
data_result.loc[:,'기준_날짜_str'] = data_result.loc[:,'기준_날짜'].astype(str)

# %%
data_result.loc[arr_index,'날짜'] = data_result.loc[arr_index,'기준_날짜_str'] + ' ' + data_result.loc[arr_index,'기준_시간_d']

# %%
data_result.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 32148 entries, 0 to 32529
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   기준_날짜      32148 non-null  int64
#  1   집계_기준      32148 non-null  str
#  2   시작_대여소_ID  32148 non-null  str
#  3   시작_대여소명    32148 non-null  str
#  4   종료_대여소_ID  32148 non-null  str
#  5   종료_대여소명    32055 non-null  str
#  6   전체_건수      32148 non-null  float64
#  7   전체_이용_분    31831 non-null  float64
#  8   전체_이용_거리   31831 non-null  float64
#  9   기준_시간      32148 non-null  float64
#  10  datetime   32148 non-null  datetime64[us]
#  11  hour       32148 non-null  float64
#  12  요일         32148 non-null  str
# dtypes: datetime64[us](1), float64(5), int64(1), str(6)
# memory usage: 6.4 MB

# %%
holiday = ['20240101', '20240209', '20240210', '20240211', '20240212',
'20240301', '20240410', '20240505', '20240506', '20240515',
'20240606', '20240815', '20240916', '20240917', '20240918',
'20241003', '20241009', '20241225']

# %%
data_result.drop(
  '휴일',
  axis='columns',
  inplace=True
)

# %%
# 휴일 표시
for index in data_result.index:
  isHoliday = False
  for d in holiday:
    dd = pd.to_datetime(d)
    if dd.month == data_result.loc[index,'datetime'].month and dd.day ==  data_result.loc[index,'datetime'].day :
      isHoliday = True
      break
  
  data_result.loc[index,'휴일'] = isHoliday
   
  # print(data_result.loc[index,'datetime'].month)

# %%
holiday
# Out:
# ['20240101',
#  '20240209',
#  '20240210',
#  '20240211',
#  '20240212',
#  '20240301',
#  '20240410',
#  '20240505',
#  '20240506',
#  '20240515',
#  '20240606',
#  '20240815',
#  '20240916',
#  '20240917',
#  '20240918',
#  '20241003',
#  '20241009',
#  '20241225']

# %%
data_result[data_result.기준_날짜 == 20240105]
# Out:
#         기준_날짜 집계_기준 시작_대여소_ID    시작_대여소명 종료_대여소_ID     종료_대여소명  전체_건수  \
# 214  20240105  도착시간   ST-3126  진관동_096_1    ST-453   진관동_038_9    1.0
# 216  20240105  도착시간   ST-1027  진관동_038_1   ST-2781   진관동_069_2    1.0
# 217  20240105  출발시간   ST-3126  진관동_096_1    ST-453   진관동_038_9    1.0
# 219  20240105  도착시간   ST-3126  진관동_096_1   ST-2778  불광1동_051_1    1.0
# 220  20240105  출발시간   ST-3126  진관동_096_1   ST-2778  불광1동_051_1    1.0
# 221  20240105  출발시간   ST-1027  진관동_038_1   ST-2781   진관동_069_2    1.0
# 222  20240105  출발시간   ST-2263  진관동_108_6    ST-453   진관동_038_9    1.0
# 223  20240105  출발시간   ST-3126  진관동_096_1   ST-3126   진관동_096_1    1.0
# 224  20240105  도착시간   ST-2263  진관동_108_6    ST-469   진관동_108_7    1.0
# 225  20240105  출발시간   ST-2263  진관동_108_6    ST-452   진관동_013_1    1.0
# 226  20240105  도착시간   ST-3126  진관동_096_1   ST-3126   진관동_096_1    1.0
# 227  20240105  도착시간   ST-2263  진관동_108_6    ST-453   진관동_038_9    1.0
# ...

# %%
data_result[data_result['집계_기준'] == '출발시간'].groupby(by=['시작_대여소_ID','기준_날짜','hour']).hour.count()
# Out:
# 시작_대여소_ID  기준_날짜     hour
# ST-1027    20240101  4.0     1
#                      9.0     1
#                      10.0    1
#                      12.0    1
#                      13.0    1
#                             ..
# ST-3126    20241231  13.0    1
#                      16.0    1
#                      17.0    2
#                      18.0    2
#                      19.0    1
# Name: hour, Length: 9522, dtype: int64

# %%
data_result.groupby(by=['시작_대여소_ID','기준_날짜','hour']).hour.count()
# Out:
# 시작_대여소_ID  기준_날짜     hour
# ST-1027    20240101  4.0     2
#                      9.0     2
#                      10.0    1
#                      11.0    1
#                      12.0    2
#                             ..
# ST-3126    20241231  13.0    2
#                      16.0    1
#                      17.0    5
#                      18.0    3
#                      19.0    3
# Name: hour, Length: 10813, dtype: int64

# %%
data_result['datetime'].m
# Out:
# 0       2024-01-01 16:45:00
# 1       2024-01-01 16:50:00
# 2       2024-01-01 16:35:00
# 3       2024-01-01 16:30:00
# 4       2024-01-01 14:00:00
#                 ...
# 32525   2024-12-31 19:00:00
# 32526   2024-12-31 07:35:00
# 32527   2024-12-31 19:55:00
# 32528   2024-12-31 09:50:00
# 32529   2024-12-31 08:00:00
# Name: datetime, Length: 32148, dtype: datetime64[us]

# %%
pd.to_datetime(data_result['기준_날짜_str'].astype(str) +' '+ data_result['기준_시간_str_dd'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 pd.to_datetime(data_result['기준_날짜_str'].astype(str) +' '+ data_result['기준_시간_str_dd'])
#
# File c:\Users\tj\anaconda3\envs\py312\Lib\site-packages\pandas\core\tools\datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1042 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\tj\anaconda3\envs\py312\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
data_result.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32530 entries, 0 to 32529
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   기준_날짜      32530 non-null  int64
#  1   집계_기준      32530 non-null  str
#  2   시작_대여소_ID  32530 non-null  str
#  3   시작_대여소명    32530 non-null  str
#  4   종료_대여소_ID  32530 non-null  str
#  5   종료_대여소명    32437 non-null  str
#  6   전체_건수      32530 non-null  float64
#  7   전체_이용_분    32213 non-null  float64
#  8   전체_이용_거리   32213 non-null  float64
#  9   기준_시간      32530 non-null  float64
#  10  기준_날짜_str  2355 non-null   str
# dtypes: float64(4), int64(1), str(6)
# memory usage: 4.5 MB

# %%
xx = data_result.groupby(by=['집계_기준','지','시작_대여소_ID']).value_counts()

# %%
xx
# Out:
# 집계_기준  시작_대여소_ID  기준_날짜     시작_대여소명    종료_대여소_ID  종료_대여소명     전체_건수  전체_이용_분  전체_이용_거리  기준_시간
# 도착시간   ST-1027    20240720  진관동_038_1  ST-2259    진관동_001_1   1.0    21.0     2640.0    1110.0    3
#                   20240802  진관동_006_1  ST-453     진관동_011_3   1.0    5.0      1450.0    1735.0    3
#                   20240803  진관동_006_1  ST-456     갈현2동_014_1  1.0    14.0     3670.0    1745.0    3
#                   20240805  진관동_006_1  ST-2263    진관동_004_2   1.0    4.0      975.0     1535.0    3
#                   20240719  진관동_038_1  ST-453     진관동_038_9   1.0    6.0      1264.0    1335.0    2
#                                                                                                  ..
# 출발시간   ST-3126    20241231  진관동_076_1  ST-2782    갈현1동_002_2  1.0    9.0      1812.0    1650.0    1
#                                        ST-1483    진관동_108_1   1.0    23.0     1240.0    1050.0    1
# ...

# %%
total = data_result['연간_전체건수'].sum()

# %%
data_result.drop(
  ['전체_건수',	'전체_이용_분','전체_이용_거리'],
  axis='columns',
  inplace=True
)

# %%
# 분기를 넣기
# data_result.loc[data_result[data_result.기준_날짜 < 20240401].index,'분기'] = '1분기'
# data_result.loc[data_result[(data_result.기준_날짜 >= 20240401)&(data_result.기준_날짜 < 20240701)].index,'분기'] = '2분기'
# data_result.loc[data_result[(data_result.기준_날짜 >= 20240701) & (data_result.기준_날짜 < 20241001)].index,'분기'] = '3분기'
# data_result.loc[data_result[data_result.기준_날짜 >= 20241001].index,'분기'] = '4분기'

# %%
# 기준시간을 따로 뽑아야 함. 
# 요일로 나오게 해야 함.
# 주말 여부 
# 
data_result.head()
# Out:
#       기준_날짜 집계_기준 시작_대여소_ID    시작_대여소명 종료_대여소_ID    종료_대여소명  전체_건수  전체_이용_분  \
# 0  20240101  출발시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    1.0      4.0
# 1  20240101  도착시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    1.0      4.0
# 2  20240101  도착시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    2.0      7.0
# 3  20240101  출발시간   ST-3126  진관동_096_1    ST-453  진관동_038_9    2.0      7.0
# 4  20240101  도착시간   ST-2263  진관동_108_6    ST-481  구산동_062_1    1.0     12.0
#
#    전체_이용_거리   기준_시간
# 0     612.0  1645.0
# 1     612.0  1650.0
# 2    1248.0  1635.0
# 3    1248.0  1630.0
# 4    2992.0  1400.0

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15704\1444748593.py in ?()
# ----> 1 pd.to_datetime(data_result['기준_날짜'].astype(str))
#
# c:\Users\tj\anaconda3\envs\py312\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy, errors)
#    6486         self._check_copy_deprecation(copy)
#    6487         if is_dict_like(dtype):
#    6488             if self.ndim == 1:  # i.e. Series
#    6489                 if len(dtype) > 1 or self.name not in dtype:
# -> 6490                     raise KeyError(
#    6491                         "Only the Series name can be used for "
#    6492                         "the key in Series dtype mappings."
#    6493                     )
#
# KeyError: 'Only the Series name can be used for the key in Series dtype mappings.'

# %%
str = data_result.기준_시간
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15704\2057659193.py in ?()
# ----> 1 str = data_result.기준_시간.astype(str)
#
# c:\Users\tj\anaconda3\envs\py312\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy, errors)
#    6486         self._check_copy_deprecation(copy)
#    6487         if is_dict_like(dtype):
#    6488             if self.ndim == 1:  # i.e. Series
#    6489                 if len(dtype) > 1 or self.name not in dtype:
# -> 6490                     raise KeyError(
#    6491                         "Only the Series name can be used for "
#    6492                         "the key in Series dtype mappings."
#    6493                     )
#
# KeyError: 'Only the Series name can be used for the key in Series dtype mappings.'

# %%
# Out:
# RangeIndex(start=0, stop=32530, step=1)

# %%
data_result['기준_날짜'] = data_result['기준_날짜'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15704\4267700945.py in ?()
# ----> 1 data_result['기준_날짜'] = data_result['기준_날짜'].astype(str)
#
# c:\Users\tj\anaconda3\envs\py312\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy, errors)
#    6486         self._check_copy_deprecation(copy)
#    6487         if is_dict_like(dtype):
#    6488             if self.ndim == 1:  # i.e. Series
#    6489                 if len(dtype) > 1 or self.name not in dtype:
# -> 6490                     raise KeyError(
#    6491                         "Only the Series name can be used for "
#    6492                         "the key in Series dtype mappings."
#    6493                     )
#
# KeyError: 'Only the Series name can be used for the key in Series dtype mappings.'

# %%
str.str.split('.')[0][0]
# Out:
# '1645'

# %%
# 3구역 중 필수 station 3개
mydata = df[(df.시작_대여소_ID == 'ST-1027') | (df.시작_대여소_ID =='ST-2263') | (df.시작_대여소_ID =='ST-3126')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15704\1328912729.py in ?()
#       1 # 3구역 중 필수 station 3개
# ----> 2 mydata = df[(df.시작_대여소_ID == 'ST-1027') | (df.시작_대여소_ID =='ST-2263') | (df.시작_대여소_ID =='ST-3126')]
#
# c:\Users\tj\anaconda3\envs\py312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '시작_대여소_ID'

# %%
import folium

# %%
seoul_map = folium.Map(
  location=[37.55,126.98],
  zoom_start=11
)

for 대여소_ID,위도,경도,연간_전체건수 in zip(data_result.대여소_ID, data_result.위도,data_result.경도,data_result.연간_전체건수):
  popup = folium.Popup(대여소_ID, max_width=200)
  folium.Marker(
    [위도, 경도],
    popup=popup
  ).add_to(seoul_map)

  
  folium.CircleMarker(
    [위도, 경도],
    radius=연간_전체건수/total*100*2.5,
    color = 'skyblue',
    fill=True,
    fill_color='skyblue',
    fill_opacity=0.4,
    tooltip=f"전체건수{연간_전체건수}",
  ).add_to(seoul_map)

  




seoul_map
