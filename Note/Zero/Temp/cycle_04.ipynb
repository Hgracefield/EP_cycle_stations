# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('../../Data/은평구_스테이션_군집화_1차_자전거댓수_추가.csv')
df1['시작_대여소_ID'] = df1['대여소_ID']
addr = df1['대여소_ID'].unique().tolist()
station = ['ST-1035','ST-454','ST-471']
df1
# Out:
#      대여소_ID                주소1              주소2         위도          경도  \
# 0    ST-453          진관동 86-31        구파발역 2번출구  37.636234  126.918999
# 1   ST-1483         진관2로 15-46   은평구 진관2로 15-46  37.639259  126.918907
# 2   ST-1481      진관2로 지하 15-25        구파발역 환승센터  37.638252  126.919456
# 3   ST-1329            진관3로 77      은평뉴타운구파발9단지  37.642609  126.921478
# 4   ST-2244     진관4로 26 진관고등학교              NaN  37.643509  126.924103
# ..      ...                ...              ...        ...         ...
# 93   ST-462          신사동 352-2              NaN  37.590809  126.913689
# 94   ST-463          증산동 199-8         증산역 4번출구  37.584381  126.909897
# 95  ST-2257            가좌로 255              NaN  37.591812  126.914833
# 96  ST-1034            증산동 239  디지털미디어 시티역 4번출구  37.577202  126.902351
# 97  ST-2779    은평로85 CJ드림시티 A동              NaN  37.599670  126.917160
#
#     1분기_전체건수  2분기_전체건수  3분기_전체건수  4분기_전체건수  연간_전체건수  cluster_12_custom   LCD  \
# ...

# %%
df = pd.read_csv('../../Data/Zero/section6.csv')
# df.drop('Unnamed: 0',axis=1,inplace=True)
# df = df.loc[:,['기준_날짜','시','분','집계_기준','시작_대여소_ID','종료_대여소_ID', '전체_건수','전체_이용_분','전체_이용_거리']]
df['기준_시간대'] = df['기준_시간']
df['기준_날짜'] = df['기준_날짜'].astype(int)
df.drop('기준_시간',axis=1, inplace=True)
df
# Out:
#           기준_날짜 집계_기준 시작_대여소_ID     시작_대여소명 종료_대여소_ID      종료_대여소명  전체_건수  \
# 0      20240101  출발시간    ST-454   대조동_024_1   ST-1331   응암3동_002_1    1.0
# 1      20240101  출발시간    ST-454   대조동_024_1   ST-1036    역촌동_001_1    1.0
# 2      20240101  출발시간   ST-1035  불광2동_021_1   ST-3058    진관동_038_8    1.0
# 3      20240101  출발시간    ST-454   대조동_024_1    ST-349  북가좌1동_008_1    1.0
# 4      20240101  출발시간    ST-454   대조동_024_1   ST-1025   응암1동_005_1    1.0
# ...         ...   ...       ...         ...       ...          ...    ...
# 86154  20241231  출발시간    ST-454   대조동_020_1   ST-1036    역촌동_044_1    1.0
# 86155  20241231  출발시간    ST-454   대조동_020_1    ST-455   응암1동_023_1    2.0
# 86156  20241231  출발시간    ST-454   대조동_020_1    ST-459    녹번동_043_1    1.0
# 86157  20241231  도착시간   ST-3169   구산동_060_1    ST-454    대조동_020_1    1.0
# 86158  20241231  도착시간   ST-2979   연남동_029_2    ST-454    대조동_020_1    1.0
#
#        전체_이용_분  전체_이용_거리   시   분  기준_시간대
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86159 entries, 0 to 86158
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   기준_날짜      86159 non-null  int64
#  1   집계_기준      86159 non-null  str
#  2   시작_대여소_ID  86159 non-null  str
#  3   시작_대여소명    86159 non-null  str
#  4   종료_대여소_ID  86159 non-null  str
#  5   종료_대여소명    85995 non-null  str
#  6   전체_건수      86159 non-null  float64
#  7   전체_이용_분    86159 non-null  float64
#  8   전체_이용_거리   86159 non-null  float64
#  9   시          86159 non-null  int64
#  10  분          86159 non-null  int64
#  11  기준_시간대     86159 non-null  float64
# dtypes: float64(4), int64(3), str(5)
# memory usage: 12.5 MB

# %%
df2 = pd.read_csv('../../Data/2025.csv')
# if '시' not in df2.columns:
#         df2['기준_시간대'] = pd.to_numeric(df2['기준_시간대'], errors='coerce').fillna(0).astype(int)
#         df2['시'] = (df2['기준_시간대'] // 100).astype(int)
#         df2['분'] = (df2['기준_시간대'] % 100).astype(int) 

df2.info(show_counts=True)

col = ['ST-1035','ST-454','ST-471']

# df_section6 = df1[(df1['시작_대여소_ID'].isin(col) & df1['집계_기준']=='출발시간') | (df1['종료_대여소_ID'].isin(col) & df1['집계_기준']=='도착시간')]
cond1 = (df2['시작_대여소_ID'].isin(col)) & (df2['집계_기준'] == '출발시간')
cond2 = (df2['종료_대여소_ID'].isin(col)) & (df2['집계_기준'] == '도착시간')

df_section6 = df2[cond1 | cond2]
df_section6['시'] = df_section6['기준_시간대'] / 100
df_section6['분'] = df_section6['기준_시간대'] % 100
df_section6['시'] = df_section6['시'].astype(int)
df_section6['분'] = df_section6['분'].astype(int)
df_section6.sort_values(['기준_날짜','시','분'],ascending=True,inplace=True)
df_section6.reset_index(drop=True, inplace=True)
df_section6
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1853028 entries, 0 to 1853027
# Data columns (total 10 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   기준_날짜      1853028 non-null  int64
#  1   집계_기준      1853028 non-null  str
#  2   기준_시간대     1853028 non-null  float64
#  3   시작_대여소_ID  1853028 non-null  str
#  4   시작_대여소명    1852456 non-null  str
#  5   종료_대여소_ID  1853028 non-null  str
#  6   종료_대여소명    1845894 non-null  str
#  7   전체_건수      1853028 non-null  int64
#  8   전체_이용_분    1853028 non-null  int64
#  9   전체_이용_거리   1853028 non-null  int64
# dtypes: float64(1), int64(4), str(5)
# memory usage: 241.0 MB
#           기준_날짜 집계_기준  기준_시간대 시작_대여소_ID     시작_대여소명 종료_대여소_ID     종료_대여소명  \
# 0      20250109  출발시간     5.0    ST-454   대조동_020_1   ST-3169   구산동_060_1
# 1      20250109  출발시간    10.0    ST-454   대조동_020_1   ST-3169   구산동_060_1
# 2      20250109  출발시간    10.0    ST-454   대조동_020_1    ST-481   구산동_029_1
# ...

# %%
total = pd.concat([df, df_section6],axis=0)
total
# Out:
#           기준_날짜 집계_기준 시작_대여소_ID     시작_대여소명 종료_대여소_ID      종료_대여소명  전체_건수  \
# 0      20240101  출발시간    ST-454   대조동_024_1   ST-1331   응암3동_002_1    1.0
# 1      20240101  출발시간    ST-454   대조동_024_1   ST-1036    역촌동_001_1    1.0
# 2      20240101  출발시간   ST-1035  불광2동_021_1   ST-3058    진관동_038_8    1.0
# 3      20240101  출발시간    ST-454   대조동_024_1    ST-349  북가좌1동_008_1    1.0
# 4      20240101  출발시간    ST-454   대조동_024_1   ST-1025   응암1동_005_1    1.0
# ...         ...   ...       ...         ...       ...          ...    ...
# 84828  20251231  출발시간   ST-1035  불광2동_020_1   ST-1035   불광2동_020_1    1.0
# 84829  20251231  도착시간   ST-1038  불광2동_042_1   ST-1035   불광2동_020_1    1.0
# 84830  20251231  도착시간   ST-3169   구산동_060_1   ST-1035   불광2동_020_1    1.0
# 84831  20251231  도착시간   ST-1035  불광2동_020_1   ST-1035   불광2동_020_1    1.0
# 84832  20251231  출발시간    ST-454   대조동_020_1    ST-479    역촌동_080_1    1.0
#
#        전체_이용_분  전체_이용_거리   시   분  기준_시간대
# ...

# %%
total.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 170992 entries, 0 to 84832
# Data columns (total 12 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   기준_날짜      170992 non-null  int64
#  1   집계_기준      170992 non-null  str
#  2   시작_대여소_ID  170992 non-null  str
#  3   시작_대여소명    170975 non-null  str
#  4   종료_대여소_ID  170992 non-null  str
#  5   종료_대여소명    170658 non-null  str
#  6   전체_건수      170992 non-null  float64
#  7   전체_이용_분    170992 non-null  float64
#  8   전체_이용_거리   170992 non-null  float64
#  9   시          170992 non-null  int64
#  10  분          170992 non-null  int64
#  11  기준_시간대     170992 non-null  float64
# dtypes: float64(4), int64(3), str(5)
# memory usage: 26.1 MB

# %%
import pandas as pd
import numpy as np

# -----------------------------
# 0) 기본 전처리
# -----------------------------
df1['LCD'] = pd.to_numeric(df1['LCD'], errors='coerce').fillna(0)
df1['QR'] = pd.to_numeric(df1['QR'], errors='coerce').fillna(0)
df1['capacity'] = df1['LCD'] + df1['QR']

total['기준_날짜'] = pd.to_datetime(total['기준_날짜'].astype(str), format='%Y%m%d', errors='coerce')

# -----------------------------
# 1) 출발 / 도착 집계
# -----------------------------
start_df = total[total['집계_기준'].astype(str).str.contains('출발', na=False)].copy()
end_df   = total[total['집계_기준'].astype(str).str.contains('도착', na=False)].copy()

start_cnt = (
    start_df.groupby(['기준_날짜', '시', '시작_대여소_ID'])['전체_건수']
    .sum()
    .reset_index(name='대여건수')
)

end_cnt = (
    end_df.groupby(['기준_날짜', '시', '종료_대여소_ID'])['전체_건수']
    .sum()
    .reset_index(name='반납건수')
    .rename(columns={'종료_대여소_ID': '시작_대여소_ID'})
)

# -----------------------------
# 2) flow 만들기
# -----------------------------
flow = pd.merge(
    start_cnt,
    end_cnt,
    on=['기준_날짜', '시', '시작_대여소_ID'],
    how='outer'
).fillna(0)

flow['대여건수'] = flow['대여건수'].astype(float)
flow['반납건수'] = flow['반납건수'].astype(float)
flow['순유출입'] = flow['대여건수'] - flow['반납건수']

# -----------------------------
# 3) capacity, cluster 붙이기
# -----------------------------
station_info = df1[['시작_대여소_ID', 'capacity', 'cluster_12_custom']].drop_duplicates()
flow = flow.merge(station_info, on='시작_대여소_ID', how='left')

flow['capacity'] = flow['capacity'].fillna(0)
flow['cluster_12_custom'] = flow['cluster_12_custom'].fillna(-1)

# -----------------------------
# 4) 시간 파생변수
# -----------------------------
flow['year'] = flow['기준_날짜'].dt.year
flow['month'] = flow['기준_날짜'].dt.month
flow['day'] = flow['기준_날짜'].dt.day
flow['weekday'] = flow['기준_날짜'].dt.weekday
flow['is_weekend'] = (flow['weekday'] >= 5).astype(int)

# -----------------------------
# 5) 라벨 만들기
# 현재 시점 risk로 라벨은 만들되,
# 학습 feature에는 현재 순유출입을 직접 넣지 않음
# -----------------------------
flow['risk'] = flow['순유출입'] / flow['capacity'].replace(0, np.nan)
flow['risk'] = flow['risk'].replace([np.inf, -np.inf], np.nan).fillna(0)

THRESH = 0.3
flow['가능'] = (flow['risk'] < THRESH).astype(int)

# -----------------------------
# 6) 시계열 정렬
# -----------------------------
flow = flow.sort_values(['시작_대여소_ID', '기준_날짜', '시']).reset_index(drop=True)

# -----------------------------
# 7) lag feature 만들기
# "현재 시점"이 아니라 "이전 시점" 정보만 사용
# -----------------------------
group_col = '시작_대여소_ID'

lag_cols = ['대여건수', '반납건수', '순유출입']

for col in lag_cols:
    flow[f'{col}_lag1'] = flow.groupby(group_col)[col].shift(1)
    flow[f'{col}_lag2'] = flow.groupby(group_col)[col].shift(2)
    flow[f'{col}_lag3'] = flow.groupby(group_col)[col].shift(3)
    flow[f'{col}_roll3'] = (
        flow.groupby(group_col)[col]
        .shift(1)
        .rolling(3)
        .mean()
        .reset_index(level=0, drop=True)
    )

# 이전 같은 시간대 정보
flow['순유출입_lag24'] = flow.groupby(group_col)['순유출입'].shift(24)
flow['대여건수_lag24'] = flow.groupby(group_col)['대여건수'].shift(24)
flow['반납건수_lag24'] = flow.groupby(group_col)['반납건수'].shift(24)

# -----------------------------
# 8) 결측 처리
# lag 때문에 생기는 NaN 제거
# -----------------------------
feature_cols = [
    'capacity',
    'cluster_12_custom',
    '시',
    'month',
    'day',
    'weekday',
    'is_weekend',
    '대여건수_lag1',
    '대여건수_lag2',
    '대여건수_lag3',
    '반납건수_lag1',
    '반납건수_lag2',
    '반납건수_lag3',
    '순유출입_lag1',
    '순유출입_lag2',
    '순유출입_lag3',
    '대여건수_roll3',
    '반납건수_roll3',
    '순유출입_roll3',
    '대여건수_lag24',
    '반납건수_lag24',
    '순유출입_lag24',
]

flow_model = flow.dropna(subset=feature_cols + ['가능']).copy()

# %%
total
# Out:
#            기준_날짜 집계_기준 시작_대여소_ID     시작_대여소명 종료_대여소_ID      종료_대여소명  전체_건수  \
# 0     2024-01-01  출발시간    ST-454   대조동_024_1   ST-1331   응암3동_002_1    1.0
# 1     2024-01-01  출발시간    ST-454   대조동_024_1   ST-1036    역촌동_001_1    1.0
# 2     2024-01-01  출발시간   ST-1035  불광2동_021_1   ST-3058    진관동_038_8    1.0
# 3     2024-01-01  출발시간    ST-454   대조동_024_1    ST-349  북가좌1동_008_1    1.0
# 4     2024-01-01  출발시간    ST-454   대조동_024_1   ST-1025   응암1동_005_1    1.0
# ...          ...   ...       ...         ...       ...          ...    ...
# 84828 2025-12-31  출발시간   ST-1035  불광2동_020_1   ST-1035   불광2동_020_1    1.0
# 84829 2025-12-31  도착시간   ST-1038  불광2동_042_1   ST-1035   불광2동_020_1    1.0
# 84830 2025-12-31  도착시간   ST-3169   구산동_060_1   ST-1035   불광2동_020_1    1.0
# 84831 2025-12-31  도착시간   ST-1035  불광2동_020_1   ST-1035   불광2동_020_1    1.0
# 84832 2025-12-31  출발시간    ST-454   대조동_020_1    ST-479    역촌동_080_1    1.0
#
#        전체_이용_분  전체_이용_거리   시   분  기준_시간대
# ...

# %%
train = flow_model[flow_model['year'] == 2024].copy()
test = flow_model[flow_model['year'] == 2025].copy()

X_train = train[feature_cols]
y_train = train['가능']

X_test = test[feature_cols]
y_test = test['가능']

print(X_train.shape, X_test.shape)
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# (19183, 22) (19218, 22)
# 가능
# 1    0.862482
# 0    0.137518
# Name: proportion, dtype: float64
# 가능
# 1    0.872671
# 0    0.127329
# Name: proportion, dtype: float64

# %%
train
# Out:
#            기준_날짜   시 시작_대여소_ID  대여건수  반납건수  순유출입  capacity  cluster_12_custom  \
# 24    2024-01-02  10   ST-1035   0.0   1.0  -1.0       6.0                  6
# 25    2024-01-02  11   ST-1035   1.0   1.0   0.0       6.0                  6
# 26    2024-01-02  12   ST-1035   2.0   1.0   1.0       6.0                  6
# 27    2024-01-02  13   ST-1035   1.0   1.0   0.0       6.0                  6
# 28    2024-01-02  14   ST-1035   1.0   1.0   0.0       6.0                  6
# ...          ...  ..       ...   ...   ...   ...       ...                ...
# 33651 2024-12-31  14    ST-471   0.0   1.0  -1.0      10.0                  6
# 33652 2024-12-31  16    ST-471   1.0   0.0   1.0      10.0                  6
# 33653 2024-12-31  19    ST-471   1.0   0.0   1.0      10.0                  6
# 33654 2024-12-31  21    ST-471   0.0   1.0  -1.0      10.0                  6
# 33655 2024-12-31  22    ST-471   1.0   1.0   0.0      10.0                  6
#
# ...

# %%
test
# Out:
#            기준_날짜   시 시작_대여소_ID  대여건수  반납건수  순유출입  capacity  cluster_12_custom  \
# 6487  2025-01-09   1   ST-1035   1.0   0.0   1.0       6.0                  6
# 6488  2025-01-09   5   ST-1035   0.0   1.0  -1.0       6.0                  6
# 6489  2025-01-09   6   ST-1035   0.0   2.0  -2.0       6.0                  6
# 6490  2025-01-09   7   ST-1035   0.0   3.0  -3.0       6.0                  6
# 6491  2025-01-09   8   ST-1035   0.0   4.0  -4.0       6.0                  6
# ...          ...  ..       ...   ...   ...   ...       ...                ...
# 38468 2025-12-31  17    ST-471   0.0   1.0  -1.0      10.0                  6
# 38469 2025-12-31  18    ST-471   0.0   1.0  -1.0      10.0                  6
# 38470 2025-12-31  19    ST-471   1.0   0.0   1.0      10.0                  6
# 38471 2025-12-31  20    ST-471   1.0   2.0  -1.0      10.0                  6
# 38472 2025-12-31  22    ST-471   0.0   1.0  -1.0      10.0                  6
#
# ...

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report, confusion_matrix

clf = LGBMClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=-1,
    num_leaves=31,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

clf.fit(X_train, y_train)

pred = clf.predict(X_test)
prob = clf.predict_proba(X_test)[:, 1]

print("Accuracy:", accuracy_score(y_test, pred))
print("F1:", f1_score(y_test, pred))
print("ROC-AUC:", roc_auc_score(y_test, prob))

print("\n[Confusion Matrix]")
print(confusion_matrix(y_test, pred))

print("\n[Classification Report]")
print(classification_report(y_test, pred))
# Out:
# [LightGBM] [Info] Number of positive: 16545, number of negative: 2638
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000399 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 530
# [LightGBM] [Info] Number of data points in the train set: 19183, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.862482 -> initscore=1.836063
# [LightGBM] [Info] Start training from score 1.836063
# Accuracy: 0.8712665209699241
# F1: 0.9308049449012697
# ROC-AUC: 0.7605170220443725
#
# [Confusion Matrix]
# [[  104  2343]
#  [  131 16640]]
#
# [Classification Report]
#               precision    recall  f1-score   support
#
#            0       0.44      0.04      0.08      2447
#            1       0.88      0.99      0.93     16771
#
#     accuracy                           0.87     19218
# ...

# %%
from sklearn.model_selection import TimeSeriesSplit, cross_val_score

tscv = TimeSeriesSplit(n_splits=5)

cv_scores = cross_val_score(
    LGBMClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=-1,
        num_leaves=31,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42
    ),
    X_train,
    y_train,
    cv=tscv,
    scoring='f1',
    n_jobs=-1
)

print("TimeSeries CV F1:", cv_scores)
print("TimeSeries CV F1 Mean:", cv_scores.mean())
# Out:
# [LightGBM] [Info] Number of positive: 2618, number of negative: 580
# [LightGBM] [Info] Number of positive: 7893, number of negative: 1699
# [LightGBM] [Info] Number of positive: 5166, number of negative: 1229
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001088 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 299
# [LightGBM] [Info] Number of data points in the train set: 3198, number of used features: 20
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003047 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002956 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 487
# [LightGBM] [Info] Total Bins 316
# ...

# %%
importance = pd.DataFrame({
    'feature': feature_cols,
    'importance': clf.feature_importances_
}).sort_values('importance', ascending=False)

print(importance.head(20))
# Out:
#        feature  importance
# 2            시         866
# 4          day         735
# 3        month         595
# 18  순유출입_roll3         526
# 21  순유출입_lag24         514
# 17  반납건수_roll3         502
# 5      weekday         496
# 16  대여건수_roll3         488
# 14   순유출입_lag2         419
# 19  대여건수_lag24         413
# 15   순유출입_lag3         393
# 13   순유출입_lag1         385
# 10   반납건수_lag1         367
# 7    대여건수_lag1         366
# 20  반납건수_lag24         360
# 9    대여건수_lag3         358
# 12   반납건수_lag3         340
# 11   반납건수_lag2         335
# 8    대여건수_lag2         329
# 0     capacity         171
